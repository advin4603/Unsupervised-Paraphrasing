# %%
# !pip install transformers nltk torch torchvision torchaudio conllu nltk
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.28.1)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: torch in /usr/local/lib/python3.10/dist-packages (2.0.0+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (0.15.1+cu118)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.10/dist-packages (2.0.1+cu118)
# Requirement already satisfied: conllu in /usr/local/lib/python3.10/dist-packages (4.5.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.65.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.27.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.12.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.22.4)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.13.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2022.10.31)
# Requirement already satisfied: huggingface-hub<1.0,>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.14.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.2.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch) (3.1.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch) (1.11.1)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch) (2.0.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch) (4.5.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch) (16.0.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision) (8.4.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.11.0->transformers) (2023.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch) (2.1.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (1.26.15)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.4)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch) (1.3.0)

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
from typing import *
import re
from pprint import pprint

split_sentences_broad_regex = re.compile(r"(?:\n(?:[\r\t\f\v ]*)\n)+")
split_tokens_broad_regex = re.compile(r"\s+")
sentence_end_broad_regex = re.compile(r"((?:\?|!)+(?:[\"\']*)$)")

sentence_end_period_regex = re.compile(r"(\.(?:[\"\']*)$)")

abbreviation_regex = re.compile(r"(?:(?:[a-zA-Z]+\.){2,})|(?:[A-Z]\.)")

punctuation_split_regex = re.compile(r"([,\"(){}\[\]_;:*\/—]+)|(-(?:-+))")

url_regex = re.compile(
    r"(http[s]?:\/\/(www\.)?|ftp:\/\/(www\.)?|www\.){1}([0-9A-Za-z-\.@:%_\+~#=]+)+((\.[a-zA-Z]{2,3})+)(\/(.)*)?(\?(.)*)?")
hashtag_regex = re.compile(r"#(?:[a-zA-Z0-9]+)")
mention_regex = re.compile(r"@(?:[a-zA-Z0-9]+)")
num_regex = re.compile(r"([0-9]+,)*[0-9]+(\.([0-9]*))?(k|m|b|t)", re.IGNORECASE)

remove_regex = re.compile(r"(?:[*\"_{}\[\]]+)")
remove_with_dash_regex = re.compile(r"^[-*\"_{}\[\]]+$")

token_substitute = {
    url_regex: "<URL>",
    hashtag_regex: "<HASHTAG>",
    mention_regex: "<MENTION>"
}


def is_abbreviation(token: str) -> bool:
    if abbreviation_regex.search(token):
        return True

    if token.lower().replace("\"", "").replace("\'", "") in {"dr.", "mr.", "mrs."}:
        return True

    return False


def is_num(token: str) -> bool:
    return bool(num_regex.search(token))


def tokenize_english(text: str) -> List[List[str]]:
    sentences: List[str] = split_sentences_broad_regex.split(text)
    sentences = [sentence for sentence in sentences if sentence]
    sentences_tokens: List[List[str]] = [split_tokens_broad_regex.split(sentence) for sentence in sentences]
    parsed_sentence_tokens = []
    for sentence in sentences_tokens:
        tokens = []
        for token in sentence:
            for regex, sub in token_substitute.items():
                if regex.search(token):
                    token = regex.sub(token, sub)
                    break
            if punctuation_split_regex.search(token):
                tokens.extend(punctuation_split_regex.split(token))
                continue

            tokens.append(token)
        tokens = [token for token in tokens if token]
        if tokens:
            parsed_sentence_tokens.append(tokens)

    sentences_tokens = parsed_sentence_tokens
    parsed_sentence_tokens = []
    for sentence in sentences_tokens:
        tokens = []
        for token in sentence:

            if sentence_end_broad_regex.search(token):
                tokens.extend(sentence_end_broad_regex.split(token))
                tokens = [token for token in tokens if token]
                parsed_sentence_tokens.append(tokens)
                tokens = []
                continue

            if sentence_end_period_regex.search(token) and not is_abbreviation(token):
                tokens.extend(sentence_end_period_regex.split(token))
                tokens = [token for token in tokens if token]
                parsed_sentence_tokens.append(tokens)
                tokens = []
                continue

            tokens.append(token)
        tokens = [token for token in tokens if token]
        if tokens:
            parsed_sentence_tokens.append(tokens)
    parsed_sentence_tokens = [
        [remove_regex.sub(token, "") if remove_regex.search(token) else token for token in sentence] for sentence in
        parsed_sentence_tokens]

    parsed_sentence_tokens = [
        [remove_with_dash_regex.sub(token, "") if remove_with_dash_regex.search(token) else token for token in sentence]
        for sentence in
        parsed_sentence_tokens]

    parsed_sentence_tokens = [[token.lower() for token in sentence if token] for sentence in parsed_sentence_tokens]
    parsed_sentence_tokens = [sentence for sentence in parsed_sentence_tokens if sentence]
    accumulate = []
    for s in parsed_sentence_tokens:
      accumulate.extend(s)
    return accumulate

tokenize_english("greetings")
# Out:
# ['greetings']

# %%
import torch
from torch.utils.data import Dataset, random_split
from transformers import GPT2Tokenizer, TrainingArguments, Trainer, GPT2LMHeadModel

# %%
torch.manual_seed(42)

# %%
tokenizer = GPT2Tokenizer.from_pretrained('gpt2-medium')
model = GPT2LMHeadModel.from_pretrained('gpt2-medium')
print(len(tokenizer))
tokenizer.add_special_tokens({"sep_token": "<|sep|>", "bos_token":'<|startoftext|>',
                                           "pad_token":'<|pad|>'})
print(tokenizer.all_special_tokens)
model.resize_token_embeddings(len(tokenizer))
# Out:
# 50257
# ['<|startoftext|>', '<|endoftext|>', '<|sep|>', '<|pad|>']
# Embedding(50260, 1024)

# %%
from typing import Sequence, List
from random import shuffle, randint, choice
from conllu import parse
from nltk.corpus import wordnet

stop_words = {
    "the",
    "a",
    "an",
    "and",
    "for",
    "nor",
    "neither",
    "or",
    "yet",
    "so",
    "either",
    "as",
    "but",
    "if",
    "then",
    "well",
    "however",
    "thus",
    "would",
    "could",
    "should",
    "may",
    "oh",
    "ah",
    "also"
    "is",
    "by",
    "with"
}

def get_synonyms(word: str):
    synonyms = []
    for syn in wordnet.synsets(word):
        for l in syn.lemmas():
            if l.name() != word:
              synonyms.append(l.name())
    return synonyms

def swap_random(a: List, exclude: List):
    if len(a) <= 1:
        return
    for _ in range(5):

        i, j = randint(0, len(a) - 1), randint(0, len(a) - 1)

        if a[i] in exclude or a[j] in exclude:
            continue
        a[i], a[j] = a[j], a[i]
        break

def corrupt(tokens: Sequence[str]) -> Sequence[str]:
    all_tokens = tokens
    tokens = [token for token in tokens if token not in stop_words]
    if len(tokens) == 0:
        tokens = all_tokens # if all words are stop words restore
    i = randint(1, len(tokens)//3+1)
    for _ in range(i):
        swap_random(tokens, {"!", "?", "."})
    for i, token in enumerate(tokens):
        if len(wordnet.synsets(token)) < 2:
            synonyms = get_synonyms(token)
            tokens[i] = choice(synonyms + [token])
    return tokens



def load_data():
    with open("en_ewt-ud-train.conllu", encoding="utf-8") as f:
        text = f.read()
    sentences = [tokenize_english(sentence.metadata.get("text")) for sentence in parse(text)][::2]
    return sentences

# %%
from copy import deepcopy

IGNORE_INDEX = -100

class ReconstructionDataset:
  def __init__(self, max_length=100):
    sentences = load_data()
    self.input_ids = []
    self.attn_masks = []
    self.labels = []
    for sentence in sentences:
        corrupted = corrupt(sentence)
        print(sentence)
        print(corrupted)
        print()
        sentence_ignore_len = len(tokenizer('<|startoftext|>' + " ".join(corrupted) + "<|sep|>")["input_ids"])
        encodings_dict = tokenizer('<|startoftext|>' + " ".join(corrupted) + "<|sep|>" + " ".join(sentence) + '<|endoftext|>', truncation=True,
                                    max_length=max_length, padding="max_length", add_special_tokens=True)
        input_ids = torch.tensor(encodings_dict['input_ids'])
        self.input_ids.append(input_ids)
        label = deepcopy(input_ids)
        label[:sentence_ignore_len] = IGNORE_INDEX
        self.labels.append(label)

  def __len__(self):
      return len(self.input_ids)

  def __getitem__(self, idx):
      return self.input_ids[idx], self.labels[idx]

# %%
dataset = ReconstructionDataset()
train_size = int(0.9 * len(dataset))
train_dataset, val_dataset = random_split(dataset, [train_size, len(dataset) - train_size])
# Out:
# Streaming output truncated to the last 5000 lines.
# ['700f', 'jobs', 'advertised', "aren't", '.']
#
# ['why', 'does', 'my', 'baby', 'king', 'snake', 'refuse', 'to', 'eat', '?']
# ['wherefore', 'king', 'snake', 'baby', 'does', 'my', 'refuse', 'to', 'eat', '?']
#
# ['i', 'have', 'tried', 'everything', 'i', 'can', 'to', 'get', 'him', 'to', 'eat', 'but', 'he', 'refuses', '.']
# ['i', 'have', 'tried', 'he', 'i', 'can', 'to', 'get', 'him', 'to', 'eat', 'everything', 'refuses', '.']
#
# ['as', 'far', 'as', 'i', 'know', ',', 'everything', 'is', 'as', 'good', 'as', 'it', 'can', 'be', 'where', 'his', 'aquarium', 'is', 'concerned', '.']
# ['far', 'i', 'know', ',', 'good', 'is', 'marine_museum', 'IT', 'where', 'be', 'is', 'his', 'everything', 'can', 'concerned', '.']
#
# ['he', 'has', 'been', 'going', 'to', 'the', 'bathroom', 'like', 'he', 'should', '.']
# ['to', 'he', 'been', 'going', 'he', 'has', 'bathroom', 'like', '.']
#
# ['he', 'has', 'been', 'drinking', 'water', '(', 'i', 'am', 'pretty', 'sure', 'he', 'has', 'been', 'drinking', 'it', 'out', 'of', 'his', 'bowl', ',', 'but', 'also', 'i', 'have', 'been', 'feeding', 'him', 'water', 'and', 'he', "doesn't", 'ever', 'give', 'me', 'a', 'problem', 'with', 'that', 'i', 'just', 'stick', 'his', 'head', 'near', 'the', 'water', 'and', 'he', 'sucks', 'it', 'down', '.', ')']
# ['been', 'has', 'he', 'out', 'water', '(', 'i', 'of', ',', 'sure', 'he', 'has', 'been', 'drinking', 'IT', 'stick', 'am', 'his', 'water', 'pretty', 'also', 'i', 'have', 'been', "doesn't", 'him', 'water', 'he', 'feeding', 'Pine_Tree_State', 'give', 'ever', 'problem', 'that', 'near', 'just', 'drinking', 'his', 'head', 'i', 'bowl', 'he', 'sucks', 'IT', 'down', '.', ')']
#
# ['he', 'is', 'feisty', ',', 'as', 'most', 'king', 'snakes', 'are', ',', 'but', 'he', 'is', 'a', 'very', 'nice', 'little', 'guy', 'he', 'never', 'tries', 'to', 'bite', 'or', 'anything', '.']
# ['he', 'he', 'feisty', ',', 'most', 'is', 'snakes', 'are', ',', 'very', 'anything', 'he', 'nice', 'little', 'guy', 'king', 'never', 'is', 'to', 'bite', 'tries', '.']
#
# ['i', "don't", 'know', 'why', 'he', "won't", 'eat', 'though', '!']
# ['i', "don't", 'know', 'he', 'wherefore', "won't", 'eat', 'though', '!']
#
# ['i', 'have', 'never', 'tried', 'feeding', 'him', 'a', 'pinky', 'that', 'was', 'bigger', 'around', 'than', 'he', 'is', '.']
# ['i', 'have', 'never', 'tried', 'feeding', 'him', 'little_finger', 'was', 'that', 'bigger', 'around', 'than', 'he', 'is', '.']
#
# ['he', 'crawls', 'on', 'top', 'of', 'them', 'but', 'does', 'not', 'try', 'to', 'eat', 'them', '.']
# ['he', 'crawls', 'eat', 'on', 'of', 'them', 'does', 'to', 'try', 'non', 'top', 'them', '.']
#
# ['i', 'have', 'tried', 'braining', 'both', 'live', 'and', 'dead', 'pinkies', ',', 'and', 'bloodying', 'them', 'up', 'to', 'get', 'his', 'attention', ',', 'but', 'he', "doesn't", 'care', '.']
# ['i', 'have', 'tried', 'braining', 'both', 'live', 'dead', 'pinkies', ',', 'bloodying', 'them', 'up', 'to', 'get', "doesn't", 'attention', ',', 'he', 'his', 'care', '.']
#
# ['i', 'have', 'bought', 'some', 'long', 'reptile', 'feeding', 'tweezers', 'and', 'have', 'tried', 'holding', 'the', 'pinky', 'in', 'front', 'of', 'the', "snake's", 'face', '.']
# ['i', 'tried', 'tweezer', 'some', 'long', "snake's", 'feeding', 'bought', 'little_finger', 'have', 'holding', 'have', 'in', 'front', 'of', 'reptile', 'face', '.']
#
# ['i', 'am', 'very', 'discouraged', 'and', 'sad', 'and', 'i', "don't", 'know', 'what', 'to', 'do', '.']
# ['know', 'am', 'i', 'i', 'sad', 'do', "don't", 'very', 'what', 'to', 'discouraged', '.']
#
# ["i've", 'only', 'tried', 'to', 'feed', 'him', 'one', 'at', 'a', 'time', '.']
# ["i've", 'feed', 'to', 'tried', 'only', 'him', 'time', 'at', 'one', '.']
#
# ['do', 'babies', 'this', 'small', 'hibernate', '?']
# ['this', 'babies', 'hibernate', 'small', 'do', '?']
#
# ['if', 'you', 'feed', 'him', 'too', 'many', 'he', 'could', 'just', 'not', 'be', 'hungry', '.']
# ['you', 'feed', 'be', 'too', 'many', 'he', 'just', 'non', 'him', 'hungry', '.']
#
# ['my', 'boyfriend', 'has', 'one', 'and', 'when', "she's", 'hungry', 'she', 'attacks', 'the', 'pinkie', 'right', 'away', '.']
# ['my', 'boyfriend', 'has', 'pinky', 'when', 'one', 'she', 'hungry', 'attacks', "she's", 'right', 'away', '.']
#
# ['remember', 'snakes', 'can', 'go', 'awhile', 'without', 'eating', '.']
# ['remember', 'snakes', 'can', 'eating', 'for_a_while', 'without', 'go', '.']
#
# ['king', 'snakes', 'sometimes', 'stop', 'eating', ',', 'particularly', 'during', 'the', 'cooler', 'part', 'of', 'the', 'year', '.']
# ['cooler', 'snakes', 'king', 'stop', 'eating', ',', 'particularly', 'during', 'sometimes', 'part', 'of', 'year', '.']
#
# ['if', 'the', 'snake', 'is', 'not', 'pregnant', 'or', 'shedding', ',', 'and', 'its', 'enclosure', 'is', 'properly', 'equipped', ',', 'a', 'loss', 'of', 'appetite', 'probably', 'signals', 'a', 'beginning', 'of', 'hibernation', '.']
# ['snake', 'equipped', 'probably', 'pregnant', 'beginning', ',', 'shedding', 'enclosure', 'hibernation', 'properly', 'is', ',', 'loss', 'of', 'appetency', 'not', 'is', 'information_technology', 'of', 'signals', '.']
#
# ['another', 'thing', 'that', 'can', 'cause', 'a', 'king', 'snake', 'to', 'stop', 'eating', 'is', 'shedding', '.']
# ['shedding', 'snake', 'is', 'that', 'cause', 'king', 'thing', 'to', 'stop', 'eating', 'can', 'some_other', '.']
#
# ['its', 'body', 'will', 'be', 'dull', 'looking', ',', 'too', '.']
# ['dull', 'body', 'will', 'looking', 'information_technology', 'be', ',', 'too', '.']
#
# ['for', 'example', ',', 'some', 'snakes', 'will', 'routinely', 'go', 'off', 'their', 'food', 'in', 'both', 'the', 'summer', 'and', 'winter', ',', 'feeding', 'mainly', 'in', 'spring', 'and', 'fall', '.']
# ['summer', 'fall', 'some', 'will', 'snakes', 'routinely', 'go', 'off', 'their', 'food', 'in', 'both', 'example', 'winter', ',', 'feeding', 'primarily', 'in', 'spring', ',', '.']
#
# ['you', 'see', ',', 'some', 'snakes', 'for', 'no', 'obvious', 'reason', 'will', 'simply', 'go', 'off', 'their', 'food', '.']
# ['you', 'see', ',', 'some', 'snakes', 'simply', 'obvious', 'reason', 'will', 'no', 'go', 'off', 'their', 'food', '.']
#
# ['hope', 'this', 'helped', '.']
# ['helped', 'this', 'hope', '.']
#
# ["it's", 'twice', 'my', 'size', 'and', 'eats', 'a', 'rabbit', 'once', 'a', 'month', '.']
# ["it's", 'twice', 'my', 'eats', 'size', 'rabbit', 'once', 'month', '.']
#
# ['how', 'rough', 'is', 'too', 'rough', '?']
# ['how', 'is', 'rough', 'rough', 'too', '?']
#
# ['i', 'have', 'a', '1', 'and', 'a', 'half', 'year', 'old', 'male', 'neutered', 'cat', 'and', 'a', 'new', '2', 'month', 'old', 'spayed', 'female', 'kitten', '.']
# ['i', 'year', '1', 'half', 'have', 'old', 'male', 'neutered', 'cat', 'new', '2', 'month', 'old', 'spayed', 'female', 'kitten', '.']
#
# ['the', 'next', 'day', 'i', 'let', 'her', 'out', 'of', 'the', 'bedroom', 'so', 'they', 'could', 'check', 'each', 'other', 'out', ',', 'and', 'the', 'kitten', 'hissed', 'twice', 'within', 'the', 'first', '20', 'minutes', 'of', 'meeting', 'each', 'other', 'and', 'now', 'she', 'no', 'longer', 'hisses', 'and', 'they', 'have', 'been', 'playing', '(', 'chasing', 'each', 'other', 'up', 'and', 'down', 'the', 'hall', ',', 'rolling', 'around', 'on', 'the', 'ground', 'and', 'pawing', 'at', 'each', 'other', ')', '.']
# ['next', 'day', 'i', 'let', 'her', 'out', 'of', 'bedchamber', 'they', 'check', 'each', 'other', 'out', ')', 'kitten', 'hissed', 'twice', 'within', 'first', '20', 'minutes', 'of', 'around', 'each', 'each', 'now', 'she', 'no', 'longer', 'at', 'they', 'have', 'been', 'playing', '(', 'chasing', 'each', 'other', 'up', 'down', 'hall', ',', 'rolling', 'meeting', 'on', 'ground', 'pawing', 'hisses', 'other', 'other', ',', '.']
#
# ['were', 'they', 'roughhouse', 'playing', '?']
# ['were', 'roughhouse', 'playing', 'they', '?']
#
# ['he', 'has', 'been', 'biting', 'at', 'her', 'neck', 'and', 'stomach', 'previously', 'while', 'they', 'play', 'without', 'her', 'meowing', 'or', 'anything', 'so', 'im', 'wondering', 'if', 'he', 'went', 'a', 'little', 'to', 'far', 'that', 'one', 'time', '.']
# ['he', 'has', 'been', 'little', 'at', 'im', 'neck', 'stomach', 'far', 'previously', 'they', 'play', 'without', 'her', 'meow', 'biting', 'her', 'wondering', 'he', 'went', 'anything', 'to', 'time', 'that', 'one', 'piece', '.']
#
# ['you', 'did', 'not', 'leave', 'the', 'new', 'kitten', 'in', 'the', 'room', 'long', 'enough', '.']
# ['you', 'did', 'in', 'leave', 'new', 'kitten', 'non', 'room', 'long', 'enough', '.']
#
# ['giving', 'the', 'new', 'kitten', 'her', 'own', 'small', 'territory', 'will', 'help', 'her', 'to', 'feel', 'safe', 'and', 'will', 'give', 'her', 'a', 'place', 'to', 'go', 'to', 'when', 'scared', '.']
# ['giving', 'safe', 'her', 'her', 'territory', 'small', 'own', 'will', 'help', 'her', 'to', 'feel', 'new', 'will', 'give', 'kitten', 'place', 'to', 'go', 'to', 'when', 'scared', '.']
#
# ['put', 'her', 'back', 'in', 'the', 'room', ',', 'and', 'keep', 'the', 'door', 'closed', 'for', 'a', 'week', '.']
# ['keep', 'her', 'back', 'in', 'room', ',', 'closed', 'door', 'put', 'week', '.']
#
# ['make', 'it', 'fifteen', 'the', 'next', 'day', ',', 'then', 'twenty', ',', 'and', 'so', 'on', '.']
# ['twenty', 'IT', 'day', ',', 'make', 'next', 'fifteen', ',', 'on', '.']
#
# ['she', 'will', 'start', 'to', 'calm', 'down', 'and', 'feel', 'safe', 'you', 'can', 'bet', 'she', "doesn't", 'now', '.']
# ['she', 'will', 'bet', 'feel', 'calm', 'now', 'to', 'safe', 'you', 'can', 'down', 'she', "doesn't", 'start', '.']
#
# ['she', 'will', 'be', 'able', 'to', 'sleep', 'without', 'being', 'afraid', '.']
# ['she', 'will', 'be', 'able', 'to', 'sleep', 'without', 'being', 'afraid', '.']
#
# ['when', 'the', 'door', 'opens', ',', 'he', 'will', 'get', 'that', 'the', 'one', 'room', 'is', 'hers', ',', 'and', 'he', 'will', 'be', 'ok', 'with', 'that', '.']
# ['when', 'door', 'opens', ',', 'he', 'will', 'get', 'that', 'one', 'room', 'is', 'hers', ',', 'he', 'will', 'be', 'ok', 'that', '.']
#
# ['your', 'male', 'is', 'hurting', 'her', 'to', 'put', 'her', 'in', 'her', 'place', 'biting', 'her', 'scruff', 'is', 'dominance', 'and', 'biting', 'the', 'belly', 'is', 'a', 'move', 'cats', 'use', 'when', 'hunting', 'to', 'pull', 'the', 'guts', 'out', 'of', 'their', 'prey', '.']
# ['place', 'male', 'is', 'hurting', 'her', 'your', 'put', 'her', 'of', 'her', 'to', 'in', 'her', 'nucha', 'is', 'dominance', 'biting', 'belly', 'is', 'move', 'cats', 'use', 'when', 'hunting', 'to', 'pull', 'guts', 'out', 'biting', 'their', 'prey', '.']
#
# ['give', 'them', 'time', 'to', 'set', 'up', 'their', 'territories', ',', 'and', 'once', 'you', 'bring', 'the', 'new', 'kitten', 'out', ',', 'pay', 'a', 'lot', 'of', 'attention', 'to', 'the', 'male', '.']
# ['give', 'them', 'time', 'new', ',', 'bring', 'their', 'territories', 'set', 'male', 'you', 'up', 'to', 'kitten', 'out', ',', 'pay', 'lot', 'of', 'attention', 'to', 'once', '.']
#
# ['that', 'will', 'help', 'to', 'reassure', 'him', ',', 'and', 'he', 'will', 'be', 'less', 'aggressive', 'with', 'her', '.']
# ['that', 'will', 'help', 'to', 'reassure', 'him', ',', 'be', 'will', 'aggressive', 'less', 'he', 'her', '.']
#
# ['if', 'they', 'hiss', ',', 'they', 'are', 'not', 'playing', '.']
# ['they', 'hiss', ',', 'they', 'playing', 'non', 'are', '.']
#
# ['hissing', 'is', 'ok', ',', 'unless', 'they', 'start', 'to', 'fight', '.']
# ['they', 'is', 'ok', 'hissing', 'unless', ',', 'start', 'to', 'fight', '.']
#
# ['putting', 'the', 'girl', 'in', 'her', 'territory', 'will', 'make', 'her', 'feel', 'less', 'afraid', ',', 'and', 'she', 'will', 'relax', '.']
# ['less', 'girl', 'in', 'her', 'territory', 'make', 'will', 'her', 'afraid', 'putting', 'feel', ',', 'she', 'will', 'relax', '.']
#
# ['a', 'hiss', 'is', 'basically', 'a', 'get', 'the', 'f', 'ck', 'away', 'sound', '.']
# ['hiss', 'is', 'essentially', 'get', 'f', 'sound', 'away', 'ck', '.']
#
# ['when', 'they', 'start', 'bleeding', 'that', 'means', "they're", 'really', 'fighting', '.']
# ['fighting', 'they', 'start', 'bleeding', 'that', 'means', "they're", 'really', 'when', '.']
#
# ['i', 'have', 'two', 'cats', ',', 'and', 'at', 'first', 'they', 'hissed', 'at', 'each', 'other', 'because', 'cats', 'are', 'very', 'territorial', ',', 'but', 'now', 'they', 'do', 'fight', 'and', 'play', '.']
# ['i', 'have', 'two', 'cats', ',', 'now', 'first', 'they', 'at', 'at', 'each', 'other', 'because', 'cats', 'are', 'very', 'territorial', ',', 'hissed', 'they', 'do', 'fight', 'play', '.']
#
# ['that', 'means', 'they', 'are', 'fighting', '.']
# ['means', 'fighting', 'that', 'are', 'they', '.']
#
# ['i', 'can', 'see', 'how', 'you', 'get', 'confused', 'though', '.', ':)']
# ['i', 'can', 'see', 'confused', 'you', 'get', 'how', 'though', '.', ':)']
#
# ['when', 'johnson', 'deployed', 'troops', 'in', '1964', 'he', 'was', 'advised', 'by', 'the', 'military', 'it', 'would', 'take', 'a', 'half-million', 'troops', 'about', 'ten', 'years', 'to', 'pacify', 'south', 'vietnam', '.']
# ['when', 'about', 'johnson', 'troops', 'he', '1964', 'in', 'was', 'vietnam', 'military', 'IT', 'years', 'half-million', 'troops', 'deployed', 'ten', 'to', 'pacify', 'take', 'south', 'advised', '.']
#
# ['he', 'did', 'not', 'give', 'them', 'the', 'number', 'of', 'troops', 'they', 'requested', '.']
# ['he', 'did', 'troops', 'give', 'they', 'number', 'of', 'non', 'them', 'requested', '.']
#
# ['thing', 'is', ',', 'it', 'worked', '.']
# ['thing', ',', 'information_technology', 'is', 'worked', '.']
#
# ['when', 'the', 'americans', 'swept', 'in', 'with', 'their', 'search', 'and', 'destroy', 'operations', 'the', 'communists', 'quickly', 'leaned', 'they', 'could', 'not', 'stand', 'up', 'to', 'the', 'us', 'firepower', ',', 'and', 'these', 'regular', 'troops', 'were', 'forced', 'to', 'flee', 'the', 'country', 'and', 'take', 'sanctuary', 'across', 'the', 'borders', 'in', 'laos', 'and', 'cambodia', '.']
# ['when', 'sanctuary', 'swept', 'in', 'in', 'search', 'destroy', 'operations', 'communists', 'their', 'leaned', 'they', 'not', 'stand', 'up', 'to', 'us', 'were', ',', 'americans', 'regular', 'troops', 'take', 'forced', 'to', 'take_flight', 'country', 'firepower', 'these', 'quickly', 'borders', 'across', 'laos', 'Kingdom_of_Cambodia', '.']
#
# ['however', ',', 'johnson', 'would', 'not', 'let', 'the', 'military', 'cross', 'the', 'borders', 'and', 'clean', 'out', 'the', 'communist', 'bases', '.']
# ['non', 'out', ',', 'let', 'military', 'clean', 'communist', 'cross', 'borders', 'johnson', 'bases', '.']
#
# ['the', 'communists', 'agreed', '.']
# ['communists', 'agreed', '.']
#
# ['however', ',', 'what', 'they', 'hoped', 'to', 'do', 'during', 'the', 'tet', 'offensive', 'was', 'to', 'sneak', 'past', 'the', 'americans', 'and', 'attack', 'the', 'arvn', 'in', 'the', 'urban', 'areas', 'where', 'they', 'were', 'deployed', 'doing', 'successful', 'clear', 'and', 'defend', 'operations', '.']
# [',', 'areas', 'they', 'hoped', 'to', 'doing', 'do', 'Tet', 'offensive', 'was', 'to', 'sneak', 'deployed', 'americans', 'attack', 'arvn', 'in', 'urban', 'defend', 'where', 'they', 'were', 'past', 'during', 'successful', 'clear', 'what', 'operations', '.']
#
# ['that', 'was', 'the', 'plan.']
# ['plan.', 'that', 'was']
#
# ['the', 'americans', 'detected', 'the', 'attempt', 'to', 'infiltrate', 'the', 'urban', 'areas', 'and', 'were', 'already', 'redeploying', 'troops', 'from', 'the', 'rural', 'areas', '.']
# ['americans', 'detected', 'attempt', 'from', 'infiltrate', 'urban', 'areas', 'rural', 'troops', 'redeploying', 'were', 'to', 'already', 'areas', '.']
#
# ['within', '24', 'hours', 'every', 'communist', 'assault', 'had', 'been', 'defeated', 'except', 'in', 'the', 'ancient', 'capital', 'of', 'hue', '.']
# ['within', 'had', 'assault', 'every', 'communist', 'hours', '24', 'been', 'defeated', 'except', 'in', 'hue', 'capital', 'ancient', 'of', '.']
#
# ['and', 'the', 'south', 'vietnamese', 'people', '?']
# ['vietnamese', 'south', 'people', '?']
#
# ['to', 'the', 'south', 'vietnamese', 'government…', '.']
# ['to', 'vietnamese', 'south', 'government…', '.']
#
# ['they', 'were', 'chased', 'back', 'into', 'laos', 'and', 'cambodia', 'with', 'the', 'arvn', 'in', 'hot', 'pursuit', '.']
# ['laos', 'in', 'chased', 'back', 'arvn', 'were', 'Cambodia', 'into', 'they', 'hot', 'pursuit', '.']
#
# ['all', 'he', 'had', 'to', 'do', 'for', 'a', 'complete', 'victory', 'was', 'allow', 'the', 'military', 'to', 'go', 'into', 'laos', 'and', 'cambodia', 'and', 'finish', 'off', 'the', 'shattered', 'communist', 'forces', '.']
# ['all', 'he', 'had', 'to', 'do', 'complete', 'was', 'victory', 'allow', 'military', 'to', 'go', 'into', 'laos', 'Kingdom_of_Cambodia', 'finish', 'off', 'shattered', 'communist', 'forces', '.']
#
# ['instead', 'he', 'pulled', 'the', 'military', 'off', ',', 'stopped', 'the', 'bombing', 'of', 'north', 'vietnam', ',', 'withdrew', 'from', 'the', 'presidential', 'race', ',', 'and', 'spent', 'the', 'rest', 'of', 'his', 'term', 'in', 'office', 'trying', 'to', 'surrender', 'to', 'north', 'vietnam', '.']
# ['pulled', 'he', 'instead', 'military', 'bombing', 'withdrew', 'stopped', 'of', 'off', 'his', 'vietnam', ',', ',', 'from', 'presidential', 'race', 'office', 'spent', 'rest', 'of', 'north', 'term', 'in', ',', 'trying', 'to', 'surrender', 'to', 'north', 'vietnam', '.']
#
# ['the', 'american', 'people', 'were', 'not', 'having', 'any', 'of', 'it', ',', 'and', 'elected', 'richard', 'nixon', 'to', 'fix', 'the', 'mess', 'lbj', 'had', 'made', '(', 'not', 'to', 'surrender', 'like', 'the', 'antiwar', 'movement', 'was', 'demanding', ')', '.']
# ['american', 'people', 'were', 'of', 'having', 'richard', 'not', 'made', ',', 'elected', 'any', 'Richard_Milhous_Nixon', 'to', '(', 'mess', 'lbj', 'had', 'surrender', 'fix', 'non', 'to', 'information_technology', 'like', 'antiwar', 'movement', 'was', 'demanding', ')', '.']
#
# ['but', 'that’s', 'another', 'question', '.']
# ['that’s', 'some_other', 'question', '.']
#
# ['to', 'make', 'the', 'war', 'unpalatable', 'to', 'the', 'american', 'public', '.']
# ['war', 'make', 'public', 'unpalatable', 'to', 'american', 'to', '.']
#
# ['before', 'tet', ',', 'the', 'war', 'was', 'unpopular', 'but', 'tolerable', 'to', 'the', 'majority', 'of', 'americans', 'in', 'that', 'the', 'loss', 'of', 'american', 'lives', 'was', 'seen', 'as', 'the', 'cost', 'of', 'subduing', 'the', 'vc', 'and', 'nva.']
# ['before', 'tet', ',', 'war', 'was', 'unpopular', 'tolerable', 'to', 'majority', 'of', 'americans', 'in', 'that', 'loss', 'of', 'american', 'cost', 'was', 'subduing', 'lives', 'of', 'seen', 'vc', 'nva.']
#
# ['there', 'is', 'a', 'very', 'good', 'book', 'on', 'the', 'subject', 'that', 'was', 'written', 'by', 'general', 'vo', 'nguyen', 'giap', '.']
# ['there', 'is', 'very', 'written', 'book', 'good', 'on', 'was', 'that', 'subject', 'giap', 'vo', 'nguyen', 'general', '.']
#
# ['bearded', 'dragon', 'question...', '?']
# ['bearded', 'question...', 'dragon', '?']
#
# ['i', 'have', 'a', 'basking', 'spot', 'lamp', 'that', 'says', 'it', 'is', 'a', 'double', 'reflector', 'that', 'focuses', '35%', 'more', 'light', '/', 'heat', 'and', 'provides', 'beneficial', 'uva', 'rays', 'important', 'to', 'the', 'psycholical', 'well-being', 'of', 'him', '.']
# ['i', 'welfare', 'basking', 'spot', 'lamp', 'that', 'says', 'information_technology', 'have', 'double', 'reflector', 'of', 'important', 'is', 'more', 'heat', 'uva', 'light', 'rays', 'beneficial', '/', 'provides', 'focuses', 'to', 'psycholical', '35%', 'that', 'him', '.']
#
# ['i', 'also', 'was', 'wondering', 'how', 'long', 'should', 'this', 'light', 'be', 'on', '.']
# ['i', 'likewise', 'this', 'wondering', 'how', 'was', 'on', 'light', 'be', 'long', '.']
#
# ["he's", 'getting', 'used', 'to', 'his', 'new', 'home', ',', 'but', "hasn't", 'eatin', 'yet', '.']
# ["he's", 'getting', 'used', 'to', 'his', 'new', 'home', ',', "hasn't", 'eatin', '.']
#
# ['any', 'advice', 'would', 'be', 'greatly', 'appreciated', '.']
# ['be', 'any', 'advice', 'greatly', 'appreciated', '.']
#
# ['let', 'me', 'try', 'to', 'break', 'this', 'down', 'as', 'simply', 'as', 'i', 'can', ':', 'diurnal', '(', 'active', 'during', 'the', 'day', 'time', ')', 'reptiles', 'like', 'the', 'bearded', 'dragon', 'require', '3', 'types', 'of', 'light', 'uva', ',', 'uvb', ',', 'and', 'heat', '.']
# [':', 'Maine', 'let', 'to', 'break', 'bearded', ',', 'i', 'simply', 'can', 'try', 'diurnal', '(', 'active', 'during', 'uvb', 'time', ')', 'reptile', 'require', 'day', 'dragon', 'like', '3', 'types', 'of', 'light', 'uva', 'down', 'this', ',', 'heat', '.']
#
# ['uvb', 'on', 'the', 'other', 'hand', 'can', 'only', 'be', 'reproduced', 'by', 'a', 'fluorescent', 'source', '.']
# ['source', 'on', 'hand', 'other', 'can', 'uvb', 'be', 'reproduced', 'only', 'fluorescent', '.']
#
# ['i', 'highly', 'recommend', 'that', 'you', 'do', 'not', 'use', 'coiled', '/', 'compact', 'uvb', 'bulbs', 'as', 'they', 'are', 'known', 'to', 'cause', 'severe', 'eye', 'damage', 'and', '/', 'or', 'blindness', 'in', 'reptiles', 'not', 'to', 'mention', 'they', 'have', 'trouble', 'maintaining', 'uvb', 'output', 'over', 'time', '.']
# ['i', 'mention', 'known', 'that', 'you', 'do', 'non', 'highly', 'coiled', '/', 'compact', 'uvb', 'bulbs', 'they', 'are', 'recommend', 'to', 'cause', 'severe', 'eye', 'damage', '/', 'cecity', 'in', 'they', 'use', 'to', 'not', 'reptilian', 'have', 'trouble', 'maintaining', 'uvb', 'output', 'over', 'time', '.']
#
# ['so', ',', 'to', 'answer', 'your', 'question', ',', 'no', ',', 'if', 'you', 'just', 'have', 'a', 'bulb', 'that', 'says', 'it', 'produces', 'uva', 'then', 'you', 'do', 'not', 'have', 'the', "sun's", 'rays', 'that', 'your', 'bearded', 'needs', '.']
# [',', 'have', 'answer', 'uva', 'question', ',', 'no', ',', 'you', 'just', 'have', 'bulb', 'that', 'says', 'it', 'produces', 'your', 'you', 'do', 'non', 'to', "sun's", 'rays', 'that', 'your', 'bearded', 'needs', '.']
#
# ['the', 'person', 'at', 'petsmart', 'is', 'very', 'wrong', ';', 'in', 'fact', 'it', 'is', 'always', 'a', 'good', 'idea', 'to', 'second', 'guess', 'what', 'most', 'pet', 'store', 'employees', 'tell', 'you', ';', 'they', "don't", 'have', 'the', 'best', 'track', 'record', 'regarding', 'giving', 'reliable', 'pet', 'care', 'info', '.']
# ['person', 'at', 'petsmart', 'is', 'very', 'wrong', ';', 'in', 'fact', 'IT', 'is', 'most', 'good', 'idea', 'to', 'second', 'guess', 'what', 'always', 'pet', 'store', 'employee', 'tell', 'you', 'track', 'they', "don't", 'have', 'best', ';', 'record', 'regarding', 'giving', 'reliable', 'pet', 'care', 'info', '.']
#
# ['freeze', 'dried', 'food', 'is', 'not', 'a', 'good', 'staple', 'food', 'source', ';', 'you', 'need', 'to', 'offer', 'live', 'feeder', 'insects', '.']
# ['freeze', 'dried', 'food', 'is', 'non', 'good', 'staple', 'insects', 'source', 'food', 'you', 'need', 'to', 'offer', ';', 'feeder', 'live', '.']
#
# ['live', 'food', 'is', 'also', 'higher', 'in', 'nutritional', 'value', 'than', 'freeze', 'dried', '.']
# ['than', 'food', 'is', 'likewise', 'dried', 'in', 'nutritional', 'value', 'live', 'freeze', 'higher', '.']
#
# ['wax', 'worms', 'and', 'meal', 'worms', 'should', 'only', 'be', 'offered', 'as', 'treat', 'items', ',', 'for', "variety's", 'sake', '.']
# ['treat', 'worms', 'sake', 'worms', 'wax', 'be', 'only', 'offered', 'items', ',', "variety's", 'meal', '.']
#
# ['<url>']
# ['<url>']
#
# ['mm', 'it', 'depends', 'on', 'the', 'size', 'of', 'his', 'tank', 'or', 'cage', 'or', 'whatever', 'you', 'have', 'him', 'in..atleast', 'as', 'far', 'as', "i'm", 'concerned', '.']
# ['mm', 'tank', 'have', 'on', 'size', 'it', 'his', 'of', 'depends', 'whatsoever', 'you', 'cage', 'him', 'in..atleast', 'far', "i'm", 'concerned', '.']
#
# ['either', 'way', 'you', 'also', 'need', 'to', 'keep', 'an', 'eye', 'on', 'the', 'temperature', 'if', 'you', 'are', 'using', 'a', 'dry', 'fish', 'tank', 'as', 'uv', 'lights', 'in', 'my', 'experience', 'up', 'the', 'temperature', 'significantly', 'and', 'without', 'proper', 'ventilation', 'it', 'can', 'become', 'an', 'oven', '.']
# ['way', 'you', 'as_well', 'need', 'to', 'keep', 'eye', 'on', 'temperature', 'you', 'are', 'using', 'dry', 'can', 'experience', 'lights', 'proper', 'in', 'my', 'tank', 'ventilation', 'temperature', 'significantly', 'without', 'uv', 'up', 'become', 'fish', 'it', 'oven', '.']
#
# ['that', 'lady', 'at', 'petsmart', 'is', 'a', 'disgrace', 'to', 'the', 'rest', 'of', 'us', 'petsmart', 'associates..', '.', 'sheesh', '.']
# ['that', 'lady', 'petsmart', 'sheesh', 'is', 'disgrace', 'to', 'rest', 'of', 'us', 'at', 'petsmart', '.', 'associates..', '.']
#
# ['and', 'it', 'should', 'be', 'on', '10-12', 'hours', ',', 'just', 'like', 'the', 'sun', 'would', 'be', 'up', 'for', '10-12', 'hours', 'in', 'his', 'natural', 'environment', '.']
# ['in', 'environment', 'be', 'just', 'hours', ',', '10-12', 'like', 'sun', 'on', 'up', '10-12', 'hours', 'IT', 'his', 'natural', 'be', '.']
#
# ['also', ',', 'beardies', 'often', 'do', 'not', 'eat', 'food', 'that', 'is', 'not', 'moving', ',', 'so', 'its', "anyone's", 'guess', 'whether', 'or', 'not', "he'll", 'touch', 'the', 'freeze-dried', 'crickets', 'or', 'the', 'processed', 'food', '.']
# ['is', ',', 'beardies', 'often', 'do', 'not', 'eat', 'food', 'that', 'likewise', 'not', 'moving', ',', 'information_technology', "anyone's", 'guess', 'whether', 'not', "he'll", 'touch', 'freeze-dried', 'crickets', 'processed', 'food', '.']
#
# ['also', 'try', 'green', 'leafy', 'veggies', ',', 'like', 'kale', 'and', 'spinach', '.']
# ['likewise', 'try', 'spinach', 'leafy', 'veggie', ',', 'like', 'kale', 'green', '.']
#
# ['is', 'a', 'finch', 'or', 'a', 'parakeet', 'better', '?']
# ['better', 'finch', 'paraquet', 'is', '?']
#
# ['please', 'help', 'me', '!']
# ['please', 'help', 'me', '!']
#
# ['hi', 'there', ',']
# [',', 'there', 'hi']
#
# ['heres', 'my', 'reason....', '.']
# ['my', 'heres', 'reason....', '.']
#
# ['i', 'ended', 'up', 'getting', 'a', 'pair', 'of', 'zebra', 'finches', 'for', 'christmas', '.']
# ['pair', 'ended', 'up', 'getting', 'i', 'of', 'zebra', 'finch', 'christmas', '.']
#
# ['they', 'were', 'chirping', 'and', 'doing', 'their', 'every', 'day', 'business', '.']
# ['doing', 'were', 'their', 'they', 'chirping', 'every', 'day', 'business', '.']
#
# ['they', 'are', 'quite', 'messy', 'and', 'you', 'cannot', 'hold', 'or', 'pet', 'them', '.']
# ['are', 'cannot', 'they', 'you', 'messy', 'quite', 'hold', 'pet', 'them', '.']
#
# ['they', 'dont', 'want', 'to', 'be', 'held', 'or', 'touched', '.']
# ['they', 'dont', 'want', 'to', 'be', 'touched', 'held', '.']
#
# ['i', 'still', 'have', 'them', 'and', 'they', 'are', 'doing', 'well', '.']
# ['i', 'have', 'still', 'them', 'they', 'are', 'doing', '.']
#
# ['they', 'are', 'adorable', 'they', 'have', 'beautiful', 'colors', 'and', 'personality', '.']
# ['beautiful', 'are', 'have', 'they', 'they', 'lovely', 'colors', 'personality', '.']
#
# ['first', 'of', 'all', 'they', 'are', 'very', 'tame', '.']
# ['all', 'of', 'first', 'they', 'very', 'are', 'tame', '.']
#
# ['they', 'can', 'do', 'tricks', 'and', 'they', 'arent', 'messy', '.']
# ['they', 'can', 'do', 'tricks', 'they', 'arent', 'mussy', '.']
#
# ['my', 'parents', 'even', 'plays', 'with', 'them', '.']
# ['even', 'parents', 'my', 'plays', 'them', '.']
#
# ['i', 'hope', 'this', 'helps', 'you', 'with', 'your', 'decision', '.']
# ['i', 'helps', 'this', 'hope', 'you', 'your', 'decision', '.']
#
# ['when', 'choosing', 'a', 'parakeet', 'look', 'for', 'a', 'young', 'one', '.']
# ['one', 'choosing', 'parrakeet', 'look', 'when', 'young', '.']
#
# ['look', 'for', 'a', 'lot', 'of', 'stripes', 'in', 'their', 'head', 'that', 'starts', 'from', 'the', 'beak', 'and', 'goes', 'back', 'to', 'the', 'back', 'fo', 'the', 'bird', '.']
# ['look', 'lot', 'that', 'stripes', 'in', 'their', 'head', 'beak', 'starts', 'from', 'of', 'goes', 'back', 'to', 'back', 'field-grade_officer', 'bird', '.']
#
# ['(', 'think', 'of', 'a', 'balding', 'man', 'lol', ')', 'look', 'for', 'clean', 'feathers', '.']
# ['(', 'think', 'of', 'clean', 'lol', 'man', ')', 'look', 'balding', 'feathers', '.']
#
# ['the', 'girl', 'has', 'either', 'pink', 'or', 'brown', '.']
# ['has', 'girl', 'pink', 'brown', '.']
#
# ['but', 'get', 'either', 'one', 'male', 'and', 'one', 'female', ',', 'or', 'two', 'males', '.']
# ['get', 'one', 'two', 'one', 'female', ',', 'male', 'males', '.']
#
# ['they', 'sometimes', 'dont', 'get', 'along', '(', 'you', 'know', 'how', 'some', 'girls', 'are', 'lol', 'hahahaahh', 'but', 'for', 'real', 'though', ',', 'two', 'girls', 'tend', 'to', 'fight', 'a', 'lot', '.']
# ['how', 'are', 'know', 'get', 'along', 'they', 'you', 'dont', '(', 'lot', 'though', 'hahahaahh', 'lol', 'two', 'real', 'girls', ',', 'sometimes', 'girls', 'tend', 'to', 'fight', 'some', '.']
#
# ['they', 'are', 'the', 'best', '!']
# ['they', 'best', 'are', '!']
#
# ['however', 'if', 'you', 'plan', 'on', 'getting', 'one', ',', 'then', 'get', 'more', 'than', 'one', 'at', 'the', 'same', 'time', 'they', 'need', 'company', '.']
# ['you', 'one', 'on', 'getting', 'plan', 'they', 'get', 'than', 'more', 'one', 'at', 'same', 'time', ',', 'need', 'company', '.']
#
# ['it', 'took', 'me', '4', 'days', 'to', 'get', 'the', 'new', 'one', 'to', 'be', 'able', 'to', 'step', 'on', 'and', 'eat', 'out', 'of', 'my', 'hand', '.']
# ['IT', 'took', 'out', '4', 'hand', 'to', 'get', 'new', 'one', 'to', 'my', 'able', 'to', 'step', 'on', 'eat', 'days', 'of', 'be', 'me', '.']
#
# ['honestly', 'they', 'have', 'worked', 'for', 'me', 'twice', 'with', 'my', 'parakeets', '.']
# ['twice', 'they', 'have', 'Pine_Tree_State', 'worked', 'honestly', 'my', 'parrakeet', '.']
#
# ['1', ')', 'when', 'you', 'get', 'the', 'bird', ',', 'place', 'him', 'or', 'her', 'or', 'them', 'in', 'the', 'cage', '.']
# ['1', 'him', 'when', 'you', 'get', 'bird', ',', 'place', ')', 'her', 'them', 'in', 'cage', '.']
#
# ['2', ')', 'then', 'place', 'you', 'hand', 'in', 'the', 'cage', '.']
# ['2', 'hand', ')', 'you', 'place', 'in', 'cage', '.']
#
# ['then', 'i', 'sat', 'on', 'the', 'couch', ',', 'placed', 'one', 'hand', 'in', 'the', 'cage', ',', 'holding', 'a', 'millet', 'spray', '.']
# ['placed', 'sat', 'in', 'i', ',', 'on', 'one', 'hand', 'couch', ',', 'cage', 'holding', 'millet', 'spray', '.']
#
# ['this', 'way', 'they', 'will', 'see', 'that', 'your', 'hand', 'is', 'good', 'and', 'its', 'not', 'going', 'to', 'grab', 'them', 'or', 'hurt', 'them', '.']
# ['this', 'not', 'they', 'will', 'its', 'your', 'that', 'hand', 'is', 'good', 'see', 'way', 'going', 'to', 'grab', 'them', 'hurt', 'them', '.']
#
# ['(', 'you', 'can', 'take', 'breaks', 'if', 'you', 'have', 'too', ')', 'and', 'repeat', 'the', 'steps', 'after', 'about', '2', 'hours', '.']
# ['(', 'steps', 'can', 'take', 'about', 'repeat', 'too', 'have', ')', 'you', 'hours', 'after', 'breaks', '2', 'you', '.']
#
# ['(', 'do', 'not', 'take', 'away', 'the', 'food', 'dish', 'from', 'the', 'birds', ',', 'they', 'will', 'associate', 'you', 'as', 'the', 'person', 'who', 'takes', 'away', 'their', 'food', ')', '...', '.']
# ['(', ',', 'non', 'take', 'away', 'you', 'dish', 'from', 'will', 'do', 'they', 'birds', 'associate', 'away', 'person', 'WHO', 'takes', 'food', 'their', 'food', ')', '...', '.']
#
# ['push', 'you', 'finger', 'to', 'their', 'feet', 'gently', 'and', 'say', 'up', '.']
# ['you', 'their', 'finger', 'to', 'say', 'feet', 'gently', 'push', 'up', '.']
#
# ['when', 'they', 'see', 'that', 'you', 'arnt', 'harming', 'them', ',', 'the', 'will', 'go', 'up', 'on', 'your', 'finger', 'when', 'you', 'say', 'up', '.']
# ['when', 'they', 'see', 'that', 'you', 'arnt', 'harming', 'them', ',', 'will', 'up', 'go', 'on', 'your', 'finger', 'when', 'you', 'say', 'up', '.']
#
# ['do', 'not', 'hit', ',', 'yell', ',', 'or', 'harm', 'them', '.']
# ['do', 'them', 'hit', ',', 'yell', ',', 'harm', 'not', '.']
#
# ['dont', 'give', 'up', '!']
# ['up', 'dont', 'give', '!']
#
# ['and', 'when', 'i', 'say', 'go', 'home', 'it', 'means', 'to', 'go', 'in', 'the', 'cage', '.']
# ['when', 'go', 'go', 'say', 'home', 'information_technology', 'means', 'to', 'i', 'in', 'cage', '.']
#
# ['they', 'worked', 'for', 'me', 'and', 'i', 'hope', 'they', 'worked', 'for', 'you', '!']
# ['they', 'you', 'me', 'worked', 'hope', 'they', 'i', 'worked', '!']
#
# ['and', 'thats', 'my', 'reason', 'why', 'you', 'should', 'choose', 'a', 'parakeet', 'over', 'a', 'finch', '.']
# ['thats', 'choose', 'reason', 'why', 'you', 'my', 'parrakeet', 'over', 'finch', '.']
#
# ['parakeet', '.']
# ['paraquet', '.']
#
# ['they', 'are', 'also', 'friendly', '.']
# ['friendly', 'they', 'also', 'are', '.']
#
# ['when', 'is', 'the', 'best', 'time', 'to', 'travel', 'to', 'ireland', '?']
# ['when', 'best', 'is', 'ireland', 'to', 'travel', 'to', 'time', '?']
#
# ['i', 'graduate', 'in', 'the', 'spring', ',', 'and', 'so', "we'd", 'like', 'to', 'go', 'between', 'then', 'and', 'winter', '.']
# ['i', 'graduate', 'in', ',', 'spring', "we'd", 'to', 'like', 'winter', 'between', 'go', '.']
#
# ['we', "don't", 'want', 'it', 'to', 'be', 'too', 'cold', '(', 'not', 'sure', 'when', 'exactly', 'there', 'fall', 'is..', '.', 'or', 'what', 'the', 'weather', 'is', 'really', 'like', 'there', 'during', 'our', 'autumn', 'months', '),', 'but', 'we', "don't", 'feel', 'like', 'we', 'need', 'to', 'go', 'right', 'in', 'the', 'middle', 'of', 'summer', 'either', '.']
# ['we', 'non', 'want', 'it', 'to', 'be', 'too', 'cold', '(', "don't", 'sure', 'when', 'exactly', 'there', 'fall', 'is..', '.', 'what', 'weather', 'is', 'really', 'like', 'there', 'during', 'our', 'autumn', 'months', '),', 'we', "don't", 'feel', 'like', 'we', 'need', 'to', 'go', 'right', 'in', 'middle', 'of', 'summer', '.']
#
# ['can', 'anyone', 'give', 'me', 'an', 'idea', 'of', 'when', 'the', 'best', 'time', 'for', 'us', 'to', 'go', 'to', 'ireland', 'would', 'be', '?']
# ['can', 'anyone', 'give', 'Maine', 'idea', 'to', 'when', 'best', 'time', 'us', 'to', 'go', 'of', 'ireland', 'be', '?']
#
# ['one', 'thing', 'you', 'can', 'be', 'sure', 'of', 'about', 'irish', 'weather', 'is', 'how', 'little', 'you', 'can', 'be', 'sure', 'of', '.']
# ['one', 'thing', 'about', 'be', 'can', 'sure', 'of', 'you', 'irish', 'weather', 'is', 'can', 'little', 'you', 'how', 'be', 'sure', 'of', '.']
#
# ['and', 'then', 'there’s', 'the', 'rain', '.']
# ['rain', 'there’s', '.']
#
# ['county', 'kerry', 'is', 'the', 'worst', 'affected', '.']
# ['county', 'is', 'affected', 'kerry', 'worst', '.']
#
# ['the', 'irish', 'weather', 'works', 'on', 'the', '‘four', 'seasons', 'in', 'a', 'day’', 'principle', ',', 'which', 'basic\xadally', 'means', 'that', 'you', 'can’t', 'predict', 'a', 'thing', 'when', 'it', 'comes', 'to', 'the', 'behaviour', 'of', 'the', 'sky', '.']
# ['irish', 'weather', 'works', 'on', '‘four', 'basic\xadally', 'in', 'day’', 'principle', ',', 'seasons', 'which', 'means', 'that', 'sky', 'can’t', 'predict', 'thing', 'when', 'it', 'comes', 'to', 'behaviour', 'of', 'you', '.']
#
# ['in', 'summer', ',', 'from', 'may', 'to', 'july', ',', 'the', 'days', 'are', 'reasonably', 'warm', 'and', '–', 'most', 'importantly', '–', 'very', 'long', ':', 'at', 'the', 'height', 'of', 'summer', 'you', 'won’t', 'need', 'to', 'turn', 'on', 'lights', 'until', 'after', '10pm', '.']
# ['summer', 'importantly', ',', 'from', 'days', 'July', 'are', 'reasonably', 'won’t', 'summer', 'warm', '–', 'most', 'to', '–', ',', 'until', ':', 'at', 'height', 'of', 'in', 'you', 'very', 'need', 'to', 'turn', 'on', 'lights', 'long', 'after', '10pm', '.']
#
# ['not', 'surprisingly', ',', 'most', 'of', 'the', 'yearly', 'festivals', 'occur', 'during', 'these', 'times', 'so', 'as', 'to', 'take', 'advantage', 'of', 'the', 'crowds', 'and', 'the', 'more', 'favourable', 'weather', '.']
# ['non', 'surprisingly', ',', 'most', 'of', 'during', 'festivals', 'occur', 'yearly', 'to', 'take', 'favourable', 'of', 'advantage', 'these', 'crowds', 'more', 'times', 'weather', '.']
#
# ['still', ',', 'you', 'have', 'a', 'better', 'chance', 'of', 'some', 'peace', 'and', 'quiet', ',', 'and', 'the', 'weather', 'can', 'be', 'surprisingly', 'better', 'in', 'april', 'and', 'september', 'than', 'in', 'mid-july', '–', 'again', ',', 'it’s', 'all', 'part', 'of', 'the', 'uncertainty', 'principle', '.']
# ['once_more', '–', 'you', 'have', 'better', 'chance', 'of', 'some', 'peace', 'quiet', ',', 'uncertainty', 'can', 'be', 'surprisingly', ',', 'in', 'april', 'September', 'than', 'part', 'mid-july', ',', 'still', 'better', 'in', 'all', 'it’s', 'of', 'weather', 'principle', '.']
#
# ['although', 'temperatures', 'do', 'not', 'often', 'venture', 'below', 'freezing', ',', 'winter', '(', 'december', 'to', 'february', ')', 'can', 'be', 'brutal', ',', 'for', 'huge', 'parts', 'of', 'the', 'country', '–', 'the', 'west', 'and', 'northwest', 'in', 'particular', '.']
# ['although', 'temperatures', 'do', 'not', 'often', 'venture', 'below', 'freezing', 'particular', 'winter', '(', 'december', 'to', 'february', ')', 'can', 'be', 'brutal', ',', 'huge', 'parts', 'of', 'country', '–', 'west', 'northwest', 'in', ',', '.']
#
# ['the', 'thing', 'to', 'do', 'is', 'to', 'bring', 'the', 'right', 'clothing', 'with', 'you', ',', 'clothes', 'so', 'you', 'can', 'layer', 'up', 'if', 'it', 'is', 'cold', 'and', 'take', 'off', 'layers', 'when', 'it', 'warms', 'up', '.']
# ['thing', 'take', 'do', 'is', 'bring', 'cold', 'right', 'clothing', 'you', ',', 'clothes', 'you', 'can', 'layer', 'up', 'information_technology', 'is', 'to', 'to', 'off', 'layers', 'when', 'it', 'warms', 'up', '.']
#
# ['as', 'that', 'famous', 'scotsman', 'billy', 'connolly', 'says', 'there', 'is', 'no', 'such', 'thing', 'as', 'bad', 'weather', 'just', 'the', 'wrong', 'clothes']
# ['that', 'bad', 'scotsman', 'billy', 'Maureen_Catherine_Connolly', 'says', 'there', 'famous', 'no', 'is', 'such', 'thing', 'weather', 'just', 'wrong', 'clothes']
#
# ['if', 'you', 'mean', 'the', 'republic', 'of', 'ireland', '(', 'dublin', ')', 'then', 'anytime', '.']
# ['you', 'mean', 'Irish_capital', 'of', 'ireland', '(', ')', 'republic', 'anytime', '.']
#
# ['their', 'seasons', 'are', 'the', 'same', 'as', 'all', 'the', 'countries', 'in', 'the', 'northern', 'hemisphere', 'but', 'i', 'would', 'suggest', 'fall', '.']
# ['their', 'seasons', 'are', 'fall', 'all', 'countries', 'in', 'northern', 'hemisphere', 'i', 'suggest', 'same', '.']
#
# ['september', 'for', 'example', '.']
# ['September', 'example', '.']
#
# ['to', 'explore', 'the', 'beautiful', 'countryside', 'you', 'will', 'need', 'to', 'be', 'old', 'enough', 'to', 'hire', 'a', 'car', 'because', 'public', 'transport', 'is', 'expensive', '&', 'only', 'goes', 'as', 'far', 'as', 'the', 'main', 'towns', '/', 'cities', ',', 'most', 'rural', 'places', "don't", 'have', 'a', 'bus', 'or', 'train', 'service', '.']
# ['to', 'explore', 'beautiful', 'cities', 'you', 'will', 'train', 'to', 'be', 'old', 'enough', 'to', 'hire', 'car', 'because', 'public', 'transport', 'is', 'expensive', '&', 'only', 'goes', '/', 'main', 'towns', 'far', 'countryside', ',', 'most', 'rural', 'places', "don't", 'have', 'bus', 'need', 'service', '.']
#
# ['by', 'definition', 'most', 'tourists', 'will', 'go', 'to', 'the', 'best', 'places', 'so', 'you', 'might', 'have', 'to', 'put', 'up', 'with', 'a', 'few', 'tourists', 'along', 'the', 'way', '.']
# ['you', 'most', 'tourer', 'will', 'go', 'to', 'best', 'places', 'definition', 'power', 'have', 'to', 'put', 'up', 'few', 'tourists', 'along', 'way', '.']
#
# ['we', 'only', 'had', 'a', 'few', 'sunny', 'days', 'this', 'summer', ',', 'barely', '24c', 'on', 'a', 'few', 'occasions', ',', 'more', 'like', '14c', 'most', 'days', '.']
# ['days', 'only', 'we', '24c', 'gay', 'few', 'had', 'most', ',', ',', 'this', 'on', 'few', 'occasions', 'days', 'more', 'like', '14c', 'summer', 'barely', '.']
#
# ['autumn', 'is', 'from', 'mid', 'august', 'onwards', 'as', 'far', 'as', 'the', 'weather', 'goes', 'if', 'not', 'officially', 'according', 'to', 'the', 'calender', '.']
# ['fall', 'calender', 'from', 'is', 'august', 'officially', 'far', 'weather', 'mid', 'non', 'goes', 'onward', 'to', 'according', '.']
#
# ['we', 'had', 'frosts', 'in', 'october', 'so', 'i', "wouldn't", 'advise', 'visiting', 'late', 'in', 'the', 'year', 'to', 'be', 'honest', ',', 'spring', 'time', 'is', 'your', 'best', 'bet', '.']
# ['we', 'had', 'frosts', 'in', 'Oct', ',', "wouldn't", 'advise', 'visiting', 'late', 'in', 'year', 'i', 'be', 'honest', 'to', 'spring', 'time', 'is', 'your', 'best', 'bet', '.']
#
# ['you', 'are', 'going', 'to', 'need', 'a', 'few', 'thousand', 'dollars', 'saved', 'up', 'for', 'flights', ',', 'insurance', ',', 'food', ',', 'accommodation', '&', 'spending', 'money', '.']
# ['you', 'are', 'going', 'to', 'spending', 'few', 'thousand', 'dollars', 'saved', 'up', 'flights', ',', 'insurance', ',', 'food', ',', 'accommodation', '&', 'need', 'money', '.']
#
# ['golden', 'wonder', 'killifish', 'breeding', 'help', '?']
# ['killifish', 'wonder', 'golden', 'breeding', 'help', '?']
#
# ['1', 'of', 'them', 'is', 'really', 'colorful', 'and', 'is', 'about', '6cm', 'long', '.']
# ['long', 'of', 'them', 'really', 'is', 'colorful', '6cm', 'about', 'is', '1', '.']
#
# ['the', 'last', 'one', 'is', 'colourful', 'too', 'but', 'it', 'is', 'about', '4cm', 'long', '.']
# ['last', '4cm', 'is', 'it', 'too', 'colourful', 'is', 'about', 'one', 'long', '.']
#
# ['can', 'you', 'tell', 'me', 'the', 'whole', 'process', 'of', 'breeding', 'them', 'and', 'taking', 'care', 'of', 'the', 'babies', '?']
# ['can', 'them', 'tell', 'Maine', 'whole', 'process', 'of', 'breeding', 'you', 'taking', 'care', 'babies', 'of', '?']
#
# ['wow', '!']
# ['wow', '!']
#
# ['i', 'aspire', 'to', 'your', 'feeding', 'regime', ',', 'flakes', 'early', 'and', 'something', 'live', 'later', 'in', 'the', 'day', '.']
# ['i', 'aspire', 'something', 'your', 'flakes', 'regime', ',', 'to', 'in', 'feeding', 'live', 'later', 'early', 'day', '.']
#
# ['i', 'think', 'that', 'you', 'understand', 'that', 'your', 'largest', 'and', 'smallest', 'golden', 'wonders', 'are', 'males', '.']
# ['i', 'that', 'wonders', 'you', 'understand', 'think', 'largest', 'males', 'smallest', 'golden', 'that', 'are', 'your', '.']
#
# ['if', 'you', 'have', 'plants', 'in', 'your', 'tank', '.']
# ['have', 'in', 'plants', 'you', 'your', 'tank', '.']
#
# ['if', 'conditions', 'are', 'favorable', '(', '78-82', 'f', ')', 'and', 'the', 'fish', 'are', 'obviously', 'well', 'fed', 'as', 'yours', 'are', ',', 'they', 'will', 'spawn', '.']
# ['conditions', 'f', 'favorable', '(', '78-82', 'are', ')', 'fish', 'spawn', 'patently', 'are', 'yours', ',', 'are', 'they', 'will', 'fed', '.']
#
# ['if', 'you', 'wish', 'to', 'pick', 'eggs', 'make', 'a', 'acrylic', 'spawning', 'mop', '.']
# ['you', 'wish', 'make', 'pick', 'eggs', 'to', 'acrylic', 'spawning', 'mop', '.']
#
# ['i', 'prefer', 'darker', 'colors', 'because', 'i', 'can', 'see', 'their', 'eggs', ',', 'more', 'easily', 'and', 'the', 'fish', 'look', 'better', 'next', 'to', 'them', '.']
# ['i', 'darker', 'prefer', 'colors', 'more', 'them', 'can', 'see', ',', 'eggs', 'their', 'because', 'next', 'fish', 'look', 'better', 'easily', 'to', 'i', '.']
#
# ['there', 'are', 'a', 'couple', 'ways', 'one', 'could', 'spawn', 'lineatus', 'mop', 'spawning', '&', 'water', 'incubating', 'them', 'for', 'two', 'weeks', ',', 'picking', 'eggs', 'from', 'a', 'mop', '&', 'putting', 'them', 'in', 'a', 'tray', 'of', 'treated', ',', 'seasoned', 'water', 'or', 'setting', 'up', 'the', 'parents', 'in', 'a', 'planted', 'tank', '&', 'moving', 'them', 'so', 'the', 'fry', 'can', 'hatch', 'out', 'there', '.']
# ['there', 'are', 'couple', ',', 'them', 'spawn', 'lineatus', 'them', 'up', '&', 'parents', 'incubating', 'can', 'two', 'weeks', '&', ',', 'there', 'of', 'mop', 'picking', 'putting', 'moving', 'in', 'out', 'from', 'treated', 'ways', 'seasoned', 'water', 'setting', 'spawning', '&', 'in', 'planted', 'tank', 'water', 'mop', 'them', 'fry', 'one', 'hatch', 'tray', 'eggs', '.']
#
# ['just', 'making', 'up', 'examples', ',', 'but', 'if', 'a', 'pair', 'is', 'constantly', 'together', ',', 'they', 'may', 'lay', '10-15', 'eggs', 'a', 'day', '.']
# ['just', 'making', 'pair', 'examples', ',', 'up', 'is', 'constantly', 'together', ',', 'they', 'lay', '10-15', 'eggs', 'day', '.']
#
# ['separated', 'and', 'feed', 'extremely', 'nourishing', 'stuff', ',', 'they', 'may', 'produce', 'more', '.']
# ['extremely', 'feed', 'separated', 'nourishing', 'stuff', ',', 'they', 'produce', 'more', '.']
#
# ['they', 'also', 'start', 'the', 'day', 'with', 'no', 'nicks', 'or', 'dings', 'in', 'their', 'fins', '.']
# ['they', 'day', 'nicks', 'also', 'no', 'dings', 'start', 'in', 'their', 'fins', '.']
#
# ['you', 'also', 'may', 'need', 'to', 'treat', 'the', 'incubation', 'water', '.']
# ['you', 'likewise', 'incubation', 'to', 'treat', 'need', 'water', '.']
#
# ['ironically', 'sometimes', 'it', 'is', 'wise', 'to', 'leave', 'the', 'newly', 'picked', 'eggs', 'in', 'fresh', 'tap', 'water', 'with', 'some', 'chlorination', 'to', 'kill', 'microscopic', 'critters', 'that', 'ride', 'in', 'with', 'the', 'eggs', '.']
# ['wise', 'in', 'information_technology', 'is', 'eggs', 'to', 'critter', 'freshly', 'picked', 'eggs', 'sometimes', 'fresh', 'tap', 'water', 'to', 'chlorination', 'some', 'kill', 'microscopic', 'leave', 'that', 'ride', 'in', 'ironically', '.']
#
# ['leaving', 'a', 'jar', 'with', 'a', 'dozen', 'black', 'worms', 'in', 'it', 'will', 'sate', 'the', "adult's", 'desire', 'for', 'snacks', 'and', 'they', 'are', 'more', 'likely', 'to', 'leave', 'fry', 'or', 'eggs', 'alone', '.']
# ['leaving', 'jar', 'dozen', 'fry', 'worms', 'in', 'it', 'will', 'snacks', 'alone', 'desire', 'fill', 'they', 'are', 'more', 'likely', 'black', 'leave', 'to', "adult's", 'eggs', '.']
#
# ['1', '.', 'is', 'a', 'tank', 'mate', '(', 'such', 'as', 'another', 'female', 'killie', 'or', 'a', 'cory', 'or', 'large', 'snails', ')', 'rating', 'the', 'eggs', '?']
# ['is', '.', 'mate', 'tank', '1', '(', 'such', 'another', 'female', 'killie', 'cory', 'snails', 'large', ')', 'eggs', 'rating', '?']
#
# ['3', '.', 'is', 'there', 'too', 'much', 'mineral', 'in', 'the', 'water', '?']
# ['3', '.', 'there', 'much', 'in', 'is', 'mineral', 'too', 'water', '?']
#
# ['that', 'indicates', 'that', 'they', 'thrive', 'in', 'different', 'water', 'chemistries', '.']
# ['in', 'indicates', 'that', 'they', 'thrive', 'that', 'different', 'chemistries', 'water', '.']
#
# ['winging', 'it', 'a', 'little', 'here', ',', 'a', 'hardness', 'of', '100', 'to', 'nearly', '200', 'ppm', '(', 'parts', 'per', 'million', ')', 'or', '5.8', 'to', '10.6', 'dh', 'should', 'be', 'fine', 'for', 'gardneri', '.']
# ['wing', 'it', 'little', 'here', ',', 'gardneri', 'of', '100', 'to', 'nearly', '200', 'ppm', '(', 'parts', 'to', 'million', ')', '5.8', 'hardness', '10.6', 'dh', 'be', 'fine', 'per', '.']
#
# ['they', 'include', 'a', 'number', 'of', 'minerals', 'there', 'and', 'you', 'can', 'figure', 'out', 'what', 'percentage', 'of', 'that', 'would', 'be', 'your', 'hardness', 'minerals', '(', 'calcium', ',', 'magnesium', 'and', 'iron', ')', '.']
# ['they', 'include', 'number', 'out', 'minerals', 'percentage', 'you', 'there', 'figure', 'of', 'what', 'can', 'of', 'that', 'be', 'your', 'hardness', 'mineral', 'Mg', 'calcium', ',', '(', 'iron', ')', '.']
#
# ['however', 'if', 'there', 'is', 'a', 'high', 'level', 'of', 'sodium', 'chloride', '(', 'common', 'salt', ')', 'that', 'can', 'break', 'down', 'the', 'chorion', '(', 'shell', ')', 'around', 'the', 'egg', 'and', 'allow', 'critters', 'to', 'get', 'in', 'and', 'eat', 'the', 'yoke', 'and', 'embryo', '.', ')']
# ['there', 'is', 'high', 'level', 'yoke', ')', 'chloride', '(', 'common', ')', ')', 'that', 'can', 'break', 'down', 'chorion', '(', 'shell', 'salt', 'around', 'egg', 'allow', 'critters', 'to', 'get', 'in', 'eat', 'of', 'embryo', '.', 'sodium']
#
# ['then', 'put', 'the', 'eggs', 'in', 'water', 'treated', 'a', 'couple', 'of', 'days', 'before', 'with', 'a', 'water', 'treatment', 'and', 'left', 'open', 'to', 'breathe', '.']
# ['put', 'couple', 'in', 'water', 'treated', 'eggs', 'of', 'before', 'days', 'water', 'treatment', 'left', 'open', 'to', 'breathe', '.']
#
# ['but', 'get', 'the', 'eggs', 'out', ',', 'maybe', 'rinsed', 'in', 'fresh', 'tap', 'water', 'and', 'then', 'into', 'the', 'incubation', 'water', '.']
# ['get', 'eggs', ',', 'in', 'mayhap', 'rinsed', 'out', 'fresh', 'tap', 'water', 'into', 'incubation', 'water', '.']
#
# ['after', 'a', 'number', 'of', 'people', 'began', 'complaining', 'about', 'mystery', 'deaths', 'among', 'incubating', 'eggs', ',', 'some', 'of', 'the', 'more', 'advanced', 'killie', 'people', 'began', 'suggesting', 'that', 'after', '7-8', 'days', 'of', 'incubation', ',', 'one', 'should', 'do', 'a', '100%', 'water', 'change', 'as', 'the', 'eggs', 'develop', ',', 'they', 'do', 'release', 'waste', 'material', '.']
# ...
# ['lots', 'of', ',', 'rules', 'it', 'minute', ',', 'last', 'host', 'price', 'was', 'worth', 'phantom', '.']
#
# ['i', 'then', 'called', 'the', '800', 'number', '(', 'which', 'was', 'answered', ')', 'and', 'inquired', 'about', 'last', 'minute', 'rates', '.']
# ['i', 'was', '800', 'last', '(', 'minute', 'called', 'answered', ')', 'inquired', 'about', 'number', 'which', 'rates', '.']
#
# ['the', 'room', 'was', 'supposed', 'to', 'be', 'on', 'the', '2nd', 'floor', ',', 'but', 'they', 'put', 'us', 'on', 'the', '3rd', '.']
# ['3rd', 'they', 'to', 'second', 'supposed', 'on', 'be', 'floor', ',', 'was', 'put', 'us', 'on', 'room', '.']
#
# ['in', 'other', 'words', ',', 'they', 'do', 'not', 'help', 'with', 'suitcases', ',', 'but', 'they', 'promise', 'totes', 'to', 'help', '.']
# ['in', ',', ',', 'they', 'other', 'not', 'do', 'help', 'words', 'traveling_bag', 'they', 'promise', 'totes', 'to', 'help', '.']
#
# ['so', 'no', 'totes', '.']
# ['no', 'totes', '.']
#
# ['then', 'she', 'was', 'gone', '.']
# ['she', 'was', 'gone', '.']
#
# ['rules', 'in', 'the', 'room', ':', '<hashtag>', 'if', 'you', 'drink', 'the', 'soda', 'from', 'the', 'fridge', 'in', 'your', 'room', 'you', 'must', 'prove', 'it', 'by', 'leaving', 'the', 'can', 'in', 'the', 'trash', '.']
# ['in', 'rules', 'room', 'room', 'from', 'you', 'must', 'soda', '<hashtag>', 'electric_refrigerator', 'in', 'your', ':', 'you', 'drink', 'prove', 'it', 'in', 'can', 'leaving', 'trash', '.']
#
# ['they', 'count', 'the', 'cans', 'in', 'the', 'trash', 'to', 'make', 'sure', '.']
# ['they', 'make', 'cans', 'to', 'in', 'trash', 'count', 'sure', '.']
#
# ['#', ')', 'if', 'you', 'want', 'a', 'late', 'checkout', ',', '(', 'after', '11', 'am', ')', 'they', 'charge', 'you', '$15', 'for', 'the', 'first', 'hour', ',', '$25', 'for', 'the', 'second', 'hour', ',', 'and', 'after', '2pm', "it's", 'a', 'full', 'day', 'charge', '.']
# ['#', 'late', 'checkout', 'want', 'day', 'you', ',', '11', 'charge', '(', 'am', ')', 'they', 'after', 'you', '$15', 'first', 'hour', 'full', '$25', 'second', 'hour', ',', 'after', '2pm', "it's", ',', ')', 'charge', '.']
#
# ['no', 'earlier', 'and', 'no', 'later', '.']
# ['no', 'earlier', 'no', 'later', '.']
#
# ['(', 'by', 'whom', ',', 'i', "don't", 'know', '.']
# ['(', 'whom', "don't", 'i', ',', 'know', '.']
#
# ['all', 'these', 'rules', 'are', 'posted', 'in', 'the', 'rooms', '.', ')']
# ['rooms', 'rules', 'in', ')', 'posted', 'these', 'all', '.', 'are']
#
# ['i', 'put', 'the', 'coffee', 'thing', 'in', 'hot', 'water', 'and', 'settled', 'for', 'a', 'cup', 'of', 'weak', 'coffee', '.']
# ['i', 'put', 'coffee', 'of', 'settled', 'cup', 'water', 'in', 'hot', 'thing', 'weak', 'coffee', '.']
#
# ['room', 'was', 'clean', ',', 'but', 'had', 'a', 'weird', ',', 'dated', ',', 'sink', '/', 'stove', 'combo', 'that', "didn't", 'work', '.']
# ['room', 'clean', 'was', ',', 'had', 'dated', 'sink', '/', 'stove', ',', ',', 'weird', 'jazz_band', 'that', "didn't", 'work', '.']
#
# ['no', 'tub', '.']
# ['no', 'tub', '.']
#
# ["don't", 'get', 'the', 'rooms', 'off', 'the', 'two', 'kitchens', '.']
# ["don't", 'get', 'rooms', 'off', 'two', 'kitchens', '.']
#
# ['free', 'parking', '.']
# ['parking', 'free', '.']
#
# ['quit', 'with', 'the', 'overstatements', '!']
# ['quit', 'overstatement', '!']
#
# ['the', 'truth', 'is', ',', 'in', 'my', 'and', 'my', 'dining', "partners'", 'experience', ',', 'this', 'is', 'a', 'fine', 'little', 'restaurant', 'with', 'some', 'unique', 'food', '.']
# ['fine', 'is', ',', 'experience', 'in', 'my', 'dining', "partners'", 'some', ',', 'this', 'is', 'restaurant', 'little', 'truth', 'my', 'unique', 'food', '.']
#
# ['now', ',', 'the', 'best', 'of', 'that', 'unique', 'food', 'comes', 'at', 'the', 'very', 'beginning', 'of', 'the', 'meal', '.']
# ['now', ',', 'beginning', 'of', 'that', 'unique', 'best', 'comes', 'at', 'very', 'food', 'of', 'meal', '.']
#
# ['though', 'they', 'are', 'mostly', 'excellent', ',', 'you', 'generally', "don't", 'get', 'enough', 'forkfuls', 'to', 'know', 'if', 'you', 'really', 'love', 'them', '.']
# ['them', 'are', 'they', 'mostly', 'know', ',', 'generally', "don't", 'you', 'get', 'love', 'forkfuls', 'though', 'splendid', 'you', 'really', 'enough', 'to', '.']
#
# ['then', 'again', ',', 'for', 'the', 'three', 'of', 'us', 'who', 'dined', 'together', ',', 'two', 'pieces', 'of', 'flatbread', 'left', 'us', 'fighting', 'for', 'more', ',', 'and', 'licking', 'the', 'hummus', 'from', 'our', 'fingers', '(', 'and', 'yes', ',', 'those', 'two', 'pieces', 'of', 'flatbread', 'did', 'represent', 'a', 'three-person', 'order', ')', '.']
# ['over_again', ',', 'three', 'humous', 'us', 'WHO', 'dined', 'together', ',', 'two', 'pieces', 'of', 'flatbread', 'left', 'from', 'fighting', 'more', ',', 'licking', 'of', 'us', 'our', 'fingers', '(', 'yes', ',', 'those', 'two', 'pieces', 'of', 'flatbread', 'did', 'represent', 'three-person', 'order', ')', '.']
#
# ['the', 'vegetarian', 'dishes', 'and', 'lighter', 'fare', 'were', 'almost', 'always', 'spot-on', ',', 'while', 'the', 'lamb', 'was', 'often', 'dry', 'and', '/', 'or', 'overcooked', '.']
# ['vegetarian', 'dishes', 'lighter', 'fare', 'were', 'near', '/', 'always', ',', 'piece', 'lamb', 'spot-on', 'often', 'dry', 'was', 'overcook', '.']
#
# ['dessert', 'was..', '.', 'hmmm', ',', "that's", 'interesting', ',', 'i', "don't", 'even', 'remember', 'dessert', '.']
# ['sweet', 'was..', '.', 'hmmm', ',', "that's", 'interesting', ',', 'i', "don't", 'even', 'remember', 'sweet', '.']
#
# ['oh', ',', 'yes', ',', 'the', 'chocolate', 'semifreddo', 'was', 'quite', 'good', '.']
# ['yes', ',', ',', 'good', 'semifreddo', 'was', 'quite', 'chocolate', '.']
#
# ['and', 'my', 'no', ',', 'i', 'still', "don't", 'remember', 'what', 'i', 'had', '.']
# ['my', 'no', 'still', 'i', ',', "don't", 'remember', 'what', 'i', 'had', '.']
#
# ['perhaps', 'had', 'we', 'not', 'gone', 'into', 'this', 'restaurant', 'believing', 'zahav', 'was', 'going', 'to', 'be', 'golden', 'as', 'its', 'name', 'suggests', '(', 'and', 'as', 'the', 'many', 'golden', 'reviews', 'seem', 'to', 'attest', '),', 'we', 'would', 'have', 'enjoyed', 'a', 'decent', 'little', 'expensive', 'experience', '.']
# ['perchance', 'had', 'we', 'not', 'gone', 'into', 'this', 'eatery', 'believing', 'zahav', 'was', 'going', 'to', 'be', 'golden', 'its', 'name', 'we', 'little', 'many', 'golden', 'reviews', 'seem', 'to', 'attest', '),', 'suggests', 'have', 'enjoyed', 'decent', '(', 'expensive', 'experience', '.']
#
# ['ps', ')', 'when', 'we', 'called', 'for', 'a', 'reservation', ',', 'we', 'were', 'told', 'that', '5', ':', '00', 'and', '9', ':', '30', 'were', 'their', 'only', 'openings', '.']
# ['we', 'openings', 'when', 'ps', 'their', 'reservation', ':', 'we', 'were', 'told', 'that', '5', 'were', '00', '9', ':', '30', ',', 'called', 'only', ')', '.']
#
# ['did', 'they', 'think', 'we', 'were', 'going', 'to', 'feel', 'lucky', 'to', 'get', 'any', 'reservation', 'at', 'all', ',', 'and', 'therefore', 'be', 'more', 'pleased', 'with', 'our', 'dining', 'experience', '?']
# ['reservation', 'they', 'think', ',', 'were', 'all', 'to', 'feel', 'lucky', 'therefore', 'get', 'did', 'pleased', 'at', 'going', 'we', 'to', 'be', 'more', 'any', 'our', 'dining', 'experience', '?']
#
# ['at', 'my', 'appointment', 'the', 'girl', 'helping', 'me', 'was', 'unable', 'to', 'adequately', 'lace', 'up', 'some', 'of', 'the', 'dresses', '.']
# ['at', 'of', 'appointment', 'girl', 'ME', 'helping', 'up', 'unable', 'to', 'adequately', 'lace', 'some', 'was', 'my', 'dresses', '.']
#
# ['i', 'thought', 'it', 'would', 'be', 'a', 'good', 'idea', 'to', 'see', 'how', 'a', 'few', 'that', 'i', 'liked', 'would', 'look', 'like', 'on', 'a', 'model', '(', 'by', 'looking', 'the', 'dress', 'up', 'online', ')', '.']
# ['good', 'few', 'information_technology', 'like', 'up', 'idea', 'to', 'see', 'how', 'thought', 'that', 'i', 'liked', 'look', 'be', 'on', 'model', '(', 'looking', 'dress', 'i', 'online', ')', '.']
#
# ['they', 'said', 'they', 'were', 'unable', 'to', 'tell', 'me', 'until', 'they', 'ordered', 'my', 'dress', '.']
# ['they', 'tell', 'they', 'were', 'unable', 'my', 'until', 'me', 'said', 'they', 'ordered', 'to', 'dress', '.']
#
# ['do', 'other', 'brides', 'fall', 'for', 'this', '???']
# ['other', '???', 'brides', 'this', 'fall', 'do']
#
# ["i'm", 'no', 'detective', 'but..', '.', 'uhh..', '.', 'seriously', '?!?']
# ["i'm", 'seriously', 'detective', 'but..', '.', 'uhh..', '.', 'no', '?!?']
#
# ['what', 'a', 'waste', 'of', 'time.']
# ['waste', 'time.', 'of', 'what']
#
# ['somehow', ',', 'since', 'she', 'supposedly', "doesn't", 'know', 'any', 'names', 'of', 'designers', '/', 'dresses', ',', 'after', 'i', 'told', 'her', 'the', 'designer', 'and', 'dress', 'name', 'of', 'the', 'one', 'i', 'was', 'comparing', ',', 'she', 'knew', 'exactly', 'which', 'dress', 'i', 'was', 'referring', 'to', 'and', 'disagreed', 'with', 'my', 'observation', ';', 'she', 'said', 'that', 'the', 'bodice', 'did', 'come', 'as', 'low', 'as', 'the', 'one', 'i', 'had', 'on', '.']
# ['somehow', 'exactly', 'since', 'was', 'purportedly', "doesn't", 'know', 'any', 'names', 'of', 'designers', '/', 'dresses', ',', 'after', 'i', 'told', 'her', 'designer', 'bodice', 'name', 'of', 'one', 'i', 'she', 'comparing', ',', 'she', 'knew', ',', 'which', 'dress', 'i', 'was', 'referring', 'to', 'disagreed', 'my', 'observation', ';', 'she', 'said', 'that', 'dress', 'did', 'come', 'low', 'one', 'i', 'had', 'on', '.']
#
# ['say', 'something', 'like', ',', 'huh', '.']
# ['say', 'something', 'like', ',', 'huh', '.']
#
# ['unless', 'you', 'want', 'to', 'take', 'the', 'tell', 'the', 'customer', 'how', 'wrong', 'she', 'is', 'and', 'try', 'and', 'force', 'her', 'into', 'a', 'dress', "she's", 'obviously', 'not', 'loving', 'approach', 'which', 'will', 'likely', 'get', 'you..', '.', 'uh..', '.', 'nowhere', '.']
# ['unless', 'you', 'want', 'to', 'take', 'how', 'customer', 'tell', 'wrong', 'she', 'is', 'try', "she's", 'uh..', 'into', 'dress', 'force', 'plainly', 'non', 'loving', 'approach', 'which', 'will', 'likely', 'get', 'you..', '.', 'her', '.', 'nowhere', '.']
#
# ['other', 'shops', 'around', 'this', 'city', 'have', 'much', 'nicer', 'and', 'more', 'transparent', 'owners', '.']
# ['owners', 'much', 'around', 'this', 'city', 'have', 'shops', 'nicer', 'more', 'transparent', 'other', '.']
#
# ['i', 'felt', 'very', 'much', 'like', 'wedding', 'gallery', 'was', 'being', 'dishonest', 'and', 'i', "wouldn't", 'trust', 'them', 'to', 'lace', 'me', 'up', 'in', 'another', 'gown', 'let', 'alone', 'trust', 'them', 'with', 'the', 'gown', 'i', 'will', 'wear', 'on', 'the', 'most', 'important', 'day', 'of', 'my', 'life', '.']
# ['wear', 'felt', 'like', 'much', 'let', 'wedding', 'gallery', 'was', 'being', 'dishonest', 'i', "wouldn't", 'to', 'them', 'trust', 'important', 'ME', 'up', 'in', 'some_other', 'gown', 'trust', 'alone', 'very', 'them', 'gown', 'i', 'will', 'my', 'life', 'most', 'lace', 'day', 'of', 'i', 'on', '.']
#
# ['after', 'happily', 'visiting', "sear's", 'automotives', 'in', 'the', 'past', ',', 'i', 'was', 'shocked', 'at', 'the', 'horrible', 'service', 'received', 'at', 'their', 'greensboro', 'location', '.']
# ['after', 'happily', 'horrible', ',', 'their', 'shocked', 'past', 'location', "sear's", 'automotives', 'in', 'at', 'visiting', 'service', 'received', 'at', 'was', 'Greensboro', 'i', '.']
#
# ['i', 'waited', 'about', '20', 'minutes', 'in', 'the', 'store', 'part', 'before', 'anyone', 'was', 'able', 'to', 'assist', 'me', 'and', 'was', 'then', 'told', 'to', 'pull', 'my', 'car', 'into', 'the', 'shop', '(', 'that', 'is', 'apparently', 'what', 'you', 'are', 'supposed', 'to', 'do', ',', 'but', 'the', 'big', 'signs', 'pointing', 'you', 'that', 'way', 'are', 'for', 'some', 'reason', 'kept', 'inside', 'the', 'garage', ',', 'so', 'you', "don't", 'see', 'them', 'drving', 'up', ',', 'and', 'they', 'purposely', 'block', 'the', 'front', 'pull-up', 'that', 'all', 'other', "sear's", 'use', ')', '.']
# ['i', 'waited', 'about', '20', 'minutes', 'kept', 'store', 'part', 'before', 'anyone', 'was', 'able', 'to', 'assist', 'me', 'was', 'told', 'to', 'pull', 'my', 'car', 'into', 'shop', '(', 'that', 'is', 'apparently', 'what', 'you', 'are', 'supposed', 'to', 'do', ',', 'big', 'signs', 'pointing', 'you', 'that', 'way', 'are', 'some', 'reason', 'in', 'inside', 'garage', ',', 'you', "don't", 'see', 'them', 'drving', 'up', ',', 'they', 'by_choice', 'block', 'front', 'pull-up', 'that', 'all', 'other', "sear's", 'use', ')', '.']
#
# ['once', 'i', 'returned', 'to', 'pick', 'up', 'my', 'car', ',', 'you', 'can', 'believe', 'i', 'spent', 'quite', 'a', 'bit', 'more', 'time', 'standing', 'around', 'waiting', '.']
# ['once', 'bit', 'returned', 'spent', 'pick', 'up', 'my', 'car', ',', 'you', 'i', 'believe', 'i', 'to', 'quite', 'can', 'more', 'time', 'standing', 'around', 'waiting', '.']
#
# ['once', 'i', 'actually', 'got', 'back', 'in', 'my', 'car', ',', 'it', 'was', 'dirty', 'and', 'had', 'grease', 'all', 'over', 'the', 'steering', 'wheel', '.']
# ['once', 'i', 'actually', 'got', 'back', 'in', 'my', 'car', ',', 'IT', 'was', 'dirty', 'had', 'wheel', 'all', 'over', 'steering', 'grease', '.']
#
# ['the', 'following', 'friday', ',', 'i', 'returned', 'with', 'my', 'car', 'to', 'go', 'ahead', 'and', 'replace', 'the', 'other', '3', 'tires', ',', 'which', 'were', 'worn', '.']
# ['to', 'Fri', 'worn', 'i', 'returned', 'ahead', 'car', 'following', ',', 'my', 'replace', 'other', '3', 'tires', 'go', 'which', 'were', ',', '.']
#
# ['once', 'again', ',', 'i', 'waited', 'for', 'quite', 'a', 'bit', 'before', 'being', 'attended', 'to', '.']
# [',', 'once_more', 'i', 'quite', 'waited', 'once', 'bit', 'before', 'being', 'attended', 'to', '.']
#
# ['he', 'said', 'it', 'was', 'the', 'same', 'tire', ',', 'and', 'verified', 'this', ',', 'after', 'checking', 'both', 'the', 'actual', 'tire', 'on', 'my', 'car', 'and', 'my', 'service', 'papers', 'from', 'earlier', 'in', 'the', 'week', '.']
# ['he', ',', 'IT', 'this', 'from', 'car', ',', 'in', 'was', 'said', 'same', 'checking', 'both', 'actual', 'tire', 'on', 'tire', 'my', 'week', 'service', 'papers', 'after', 'earlier', 'verified', 'my', '.']
#
# ['so', 'i', 'pointed', 'this', 'out', 'to', 'him', ',', 'at', 'which', 'point', 'he', 'said', 'they', 'only', 'had', 'one', 'of', 'the', 'correct', 'tires', 'in', 'stock', '.']
# ['i', 'pointed', 'this', 'out', 'to', 'had', ',', 'stock', 'him', 'he', 'at', 'said', 'they', 'only', 'point', 'one', 'of', 'correct', 'tires', 'in', 'which', '.']
#
# ['so', 'i', 'got', 'just', 'my', 'other', 'rear', 'tire', 'replaced', '.']
# ['got', 'i', 'tire', 'replaced', 'other', 'rear', 'just', 'my', '.']
#
# ['over', 'two', 'hours', 'later', '(', 'and', 'ten', 'minutes', 'before', 'they', 'closed', ')', 'my', 'car', 'was', 'finally', 'finished', '.']
# ['over', 'finally', 'hours', 'later', 'car', 'ten', 'minutes', 'before', 'they', 'closed', ')', 'my', '(', 'was', 'two', 'finished', '.']
#
# ['of', 'course', ',', 'they', 'would', 'be', 'closing', 'in', '5', 'minutes', ',', 'so', 'i', 'would', 'have', 'to', 'hurry', 'up', 'or', 'get', 'it', 'the', 'next', 'day', '.']
# ['of', 'course', ',', 'they', 'be', 'closing', 'in', 'next', 'minutes', ',', 'i', 'have', 'to', 'hurry', 'up', 'information_technology', 'get', '5', 'day', '.']
#
# ['the', 'next', 'day', ',', 'no', 'one', 'could', 'find', 'my', 'wheel', 'lock', 'and', 'that', 'particular', 'technician', 'was', 'not', 'in', '.']
# ['next', 'one', ',', 'no', 'day', 'my', 'find', 'wheel', 'lock', 'particular', 'that', 'in', 'was', 'non', 'technician', '.']
#
# ['on', 'monday', 'i', 'called', 'and', 'again', 'it', 'was', 'a', 'big', 'to-do', 'to', 'find', 'anyone', 'who', 'knew', 'anything', 'about', 'it', '.']
# ['i', 'IT', 'anyone', 'called', 'once_more', 'Monday', 'was', 'big', 'kerfuffle', 'to', 'find', 'on', 'World_Health_Organization', 'knew', 'anything', 'about', 'it', '.']
#
# ['the', 'employees', 'at', 'this', "sear's", 'are', 'completely', 'apathetic', 'and', 'there', "didn't", 'seem', 'to', 'be', 'any', 'sort', 'of', 'management', 'that', 'i', 'could', 'see', '.']
# ['employee', 'this', 'at', 'seem', 'are', "didn't", 'apathetic', 'see', 'completely', 'of', "sear's", 'be', 'any', 'sort', 'to', 'management', 'that', 'i', 'there', '.']

# %%
import gc
gc.collect()
# Out:
# 8

# %%
torch.cuda.empty_cache()

# %%
training_args = TrainingArguments(output_dir='./results', num_train_epochs=3, logging_steps=100, save_steps=5000,
                                  per_device_train_batch_size=20, per_device_eval_batch_size=10,
                                  warmup_steps=10, weight_decay=0.05, logging_dir='./logs', report_to = 'none')

# %%
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=val_dataset,
    data_collator=lambda data: {'input_ids': torch.stack([f[0] for f in data]),
                                'labels': torch.stack([f[1] for f in data])}).train()
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/optimization.py:391: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
#     <div>
#
#       <progress value='849' max='849' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [849/849 20:56, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>100</td>
#       <td>1.669800</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.322700</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>0.277800</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>0.229000</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>0.217600</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>0.196100</td>
#     </tr>
#     <tr>
#       <td>700</td>
#       <td>0.165000</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>0.173000</td>
#     </tr>
#   </tbody>
# </table><p>

# %%
def print_paraphrases(sentence):
    corrupted = " ".join(corrupt(tokenize_english(sentence)))
    corrupt_in = "<|startoftext|>" + corrupted + "<|sep|>"
    generated = tokenizer(corrupt_in, return_tensors="pt").input_ids.cuda()
    sample_outputs = model.generate(generated, do_sample=True, top_k=50,
                                    max_length=300, top_p=0.95, temperature=2., num_return_sequences=20)
    for i, sample_output in enumerate(sample_outputs):
        print("{}: {}".format(i, tokenizer.decode(sample_output).split("<|sep|>")[1].split("<|endoftext|>")[0]))

# %%
print_paraphrases("Can you paraphrase this sentence.")
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 0:  this can paraphrasing sentence this sentence.
# 1:  phantom sentence : this can read as paraphrase.
# 2:  try this sentence or paraphrase thephrase.
# 3:  this then sentence can be translated as well.
# 4:  if this may you may as you paraphrase.
# 5:  this can you paraphrase and may you can paraphrase it for $50.
# 6:  this sentence will help you paraphrase if you could quote.
# 7:  this is what this can or probably i should paraphrase..
# 8:  if you can you can do the sentence paraphrase.
# 9:  so this sentences can would you summarise.
# 10:  i could sentence this as you can.
# 11:  oh yeah this can and can you paraphrase a well.
# 12:  pharmacy can you paraphrase these.
# 13:  do you realize what a sentence can possibly quote?
# 14:  this can also you remove any paribraphically, as follows and by writing your pariah sentence.
# 15:  in addition. well you could sentence and paraphrase this.
# 16:  if you can paraphrase sentence.
# 17:  this sentence can be paraphrased to make it look more simple.
# 18:  this sentence can you use with you paraphrase.
# 19:  this can you rewrite a sentence.

# %%
model.save_pretrained("paraphraser")

# %%
model_loaded = GPT2LMHeadModel.from_pretrained('paraphraser').cuda()

# %%
def print_paraphrases_loaded(sentence):
    corrupted = " ".join(corrupt(tokenize_english(sentence)))
    corrupt_in = "<|startoftext|>" + corrupted + "<|sep|>"
    generated = tokenizer(corrupt_in, return_tensors="pt").input_ids.cuda()
    sample_outputs = model_loaded.generate(generated, do_sample=True, top_k=50,
                                    max_length=300, top_p=0.95, temperature=2., num_return_sequences=20)
    for i, sample_output in enumerate(sample_outputs):
        print("{}: {}".format(i, tokenizer.decode(sample_output).split("<|sep|>")[1].split("<|endoftext|>")[0]))

# %%
print_paraphrases_loaded("hello i am a loaded model")
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 0:  came in hifi and is loaded i am am the best model the
# 1:  am hi im loaded as Model
# 2:  hi i am loaded am the model
# 3:  for the model it loaded hi am hiked hi
# 4:  how do i load hi model
# 5:  hi im loaded and he models awesome
# 6:  hi am load was loaded with a model
# 7:  hi i am preloaded Model hi
# 8:  hi ive added another model and you load me hi am
# 9:  hi my model loaded up
# 10:  hi i am loaded model
# 11:  i am loaded but its a hi am model
# 12:  i am loaded and humungous i am happy
# 13:  i am loading a model gun im hi
# 14:  me and i'm loading the model
# 15:  hi i am loading a model
# 16:  am load n pre i model ah
# 17:  loaded with the car i am a model
# 18:  i am set Hi Hi auto loader
# 19:  i am ho ho cocked with a model and am loaded with hi p

# %%
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-54-9ae82b287050> in <cell line: 1>()
# ----> 1 get_ipython().system('zip paraphraser')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_shell.py in system(self, *args, **kwargs)
#      97       kwargs.update({'also_return_output': True})
#      98
# ---> 99     output = _system_commands._system_compat(self, *args, **kwargs)  # pylint:disable=protected-access
#     100
#     101     if pip_warn:
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_system_commands.py in _system_compat(shell, cmd, also_return_output)
#     451   # is expected to call this function, thus adding one level of nesting to the
#     452   # stack.
# --> 453   result = _run_command(
#     454       shell.var_expand(cmd, depth=2), clear_streamed_output=False
#     455   )
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_system_commands.py in _run_command(cmd, clear_streamed_output)
#     165   locale_encoding = locale.getpreferredencoding()
#     166   if locale_encoding != _ENCODING:
# --> 167     raise NotImplementedError(
#     168         'A UTF-8 locale is required. Got {}'.format(locale_encoding)
#     169     )
#
# NotImplementedError: A UTF-8 locale is required. Got ANSI_X3.4-1968

# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"

# %%
# !zip -r paraphraser.zip ./paraphraser
# Out:
#   adding: paraphraser/ (stored 0%)
#   adding: paraphraser/generation_config.json (deflated 24%)
#   adding: paraphraser/pytorch_model.bin (deflated 9%)
#   adding: paraphraser/config.json (deflated 52%)
